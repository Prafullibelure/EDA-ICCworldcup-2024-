# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r'C:\Users\Admin\Downloads\ICCMatches.csv')

# %%
df.columns
# Out:
# Index(['season', 'team1', 'team2', 'date', 'match_number', 'venue', 'city',
#        'toss_winner', 'toss_decision', 'player_of_match', 'umpire1', 'umpire2',
#        'reserve_umpire', 'match_referee', 'winner', 'winner_runs',
#        'winner_wickets', 'match_type'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   season           52 non-null     int64
#  1   team1            51 non-null     object
#  2   team2            51 non-null     object
#  3   date             52 non-null     object
#  4   match_number     52 non-null     int64
#  5   venue            52 non-null     object
#  6   city             52 non-null     object
#  7   toss_winner      52 non-null     object
#  8   toss_decision    52 non-null     object
#  9   player_of_match  51 non-null     object
#  10  umpire1          52 non-null     object
#  11  umpire2          52 non-null     object
#  12  reserve_umpire   52 non-null     object
#  13  match_referee    52 non-null     object
#  14  winner           50 non-null     object
#  15  winner_runs      25 non-null     float64
#  16  winner_wickets   24 non-null     float64
# ...

# %%
df.describe()
# Out:
#        season  match_number  winner_runs  winner_wickets
# count    52.0     52.000000    25.000000       24.000000
# mean   2024.0     27.961538    40.240000        6.416667
# std       0.0     16.453096    38.411457        2.244155
# min    2024.0      1.000000     1.000000        2.000000
# 25%    2024.0     13.750000    12.000000        5.000000
# 50%    2024.0     27.500000    25.000000        7.000000
# 75%    2024.0     42.250000    50.000000        8.000000
# max    2024.0     55.000000   134.000000       10.000000

# %%
plt.figure(figsize=(9,3))
plt.scatter(df['toss_winner'], df['toss_decision'])
plt.xlabel("toss_winner") 
plt.ylabel("toss_decision")  
plt.show()

# %%
def bar_plot(variable):
    varValue = df[variable].value_counts()  
    plt.figure(figsize=(16,3))
    plt.bar(varValue.index, varValue)
    plt.xticks(varValue.index,varValue.index.values) 
    plt.ylabel("Frequency")  
    plt.title(variable)
    plt.show()
    print("{}: \n {}".format(variable,varValue))

# %%
import matplotlib.pyplot as plt

# %%
columns_plot=['venue','winner_runs','toss_winner','winner','season']
for i in columns_plot:
 bar_plot(i)
# Out:
# venue:
#  venue
# Kensington Oval                                      9
# Nassau County International Cricket Stadium          8
# Sir Vivian Richards Stadium                          8
# Providence Stadium                                   6
# Daren Sammy National Cricket Stadium                 6
# Brian Lara Stadium                                   5
# Arnos Vale Ground                                    5
# Grand Prairie Stadium                                4
# Central Broward Regional Park Stadium Turf Ground    1
# Name: count, dtype: int64
# winner_runs:
#  winner_runs
# 21.0     2
# 7.0      2
# 125.0    1
# 8.0      1
# 24.0     1
# 50.0     1
# 28.0     1
# 47.0     1
# 18.0     1
# 104.0    1
# 83.0     1
# 41.0     1
# 39.0     1
# 1.0      1
# 25.0     1
# 13.0     1
# 4.0      1
# 6.0      1
# 134.0    1
# 36.0     1
# 84.0     1
# 12.0     1
# 68.0     1
# Name: count, dtype: int64
# toss_winner:
#  toss_winner
# ENG        6
# AUS        5
# AFG        4
# ...

# %%
plt.hist(df['match_number'])
plt.show()

# %%
def hist_plot(variable):
    varValue = df[variable].value_counts()  
    plt.figure(figsize=(9, 3))
    plt.bar(varValue.index, varValue)
    plt.xticks(varValue.index, varValue.index.values)  
    plt.ylabel("Frequency") 
    plt.title(variable)
    plt.show()

# %%
columns_plot=['venue','winner_runs','toss_winner','winner','season']
for i in columns_plot:
 hist_plot(i)

# %%
df[['reserve_umpire','season']].groupby(['reserve_umpire'], as_index=False).mean().sort_values(by='season', ascending=False)
# Out:
#       reserve_umpire  season
# 0          A Paleker  2024.0
# 1           AG Wharf  2024.0
# 18       SJ Nogajski  2024.0
# 17       Rashid Riaz  2024.0
# 16    RK Illingworth  2024.0
# 15         RJ Tucker  2024.0
# 14  RA Kettleborough  2024.0
# 13        PR Reiffel  2024.0
# 12       Nitin Menon  2024.0
# 11          MA Gough  2024.0
# 10          L Rusere  2024.0
# 9          JS Wilson  2024.0
# 8      J Madanagopal  2024.0
# 7    HDPK Dharmasena  2024.0
# 6           CM Brown  2024.0
# 5        CB Gaffaney  2024.0
# 4        Asif Yaqoob  2024.0
# 3         Ahsan Raza  2024.0
# 2       AT Holdstock  2024.0
# 19      Sharfuddoula  2024.0

# %%
df.columns
# Out:
# Index(['season', 'team1', 'team2', 'date', 'match_number', 'venue', 'city',
#        'toss_winner', 'toss_decision', 'player_of_match', 'umpire1', 'umpire2',
#        'reserve_umpire', 'match_referee', 'winner', 'winner_runs',
#        'winner_wickets', 'match_type'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# season              0
# team1               1
# team2               1
# date                0
# match_number        0
# venue               0
# city                0
# toss_winner         0
# toss_decision       0
# player_of_match     1
# umpire1             0
# umpire2             0
# reserve_umpire      0
# match_referee       0
# winner              2
# winner_runs        27
# winner_wickets     28
# match_type          0
# dtype: int64

# %%
sns.boxplot(df['team2'])
# Out:
# <Axes: ylabel='team2'>

# %%
sns.boxplot(df['winner'])
# Out:
# <Axes: ylabel='winner'>

# %%
df['winner_wickets']=df['winner_wickets'].fillna(df['winner_wickets'].median())

# %%
df.isnull().sum()
# Out:
# season              0
# team1               1
# team2               1
# date                0
# match_number        0
# venue               0
# city                0
# toss_winner         0
# toss_decision       0
# player_of_match     1
# umpire1             0
# umpire2             0
# reserve_umpire      0
# match_referee       0
# winner              2
# winner_runs        27
# winner_wickets      0
# match_type          0
# dtype: int64

# %%
df['winner_runs']=df['winner_runs'].fillna(df['winner_runs'].median())

# %%
df.isnull().sum()
# Out:
# season             0
# team1              1
# team2              1
# date               0
# match_number       0
# venue              0
# city               0
# toss_winner        0
# toss_decision      0
# player_of_match    1
# umpire1            0
# umpire2            0
# reserve_umpire     0
# match_referee      0
# winner             2
# winner_runs        0
# winner_wickets     0
# match_type         0
# dtype: int64

# %%
df['winner'].mode()
# Out:
# 0    IND
# Name: winner, dtype: object

# %%
df['winner']=df['winner'].fillna(df['winner'].mode()[0])

# %%
df.isna().sum()
# Out:
# season             0
# team1              1
# team2              1
# date               0
# match_number       0
# venue              0
# city               0
# toss_winner        0
# toss_decision      0
# player_of_match    1
# umpire1            0
# umpire2            0
# reserve_umpire     0
# match_referee      0
# winner             0
# winner_runs        0
# winner_wickets     0
# match_type         0
# dtype: int64

# %%
df['team1'].mode()
# Out:
# 0    PNG
# 1     WI
# Name: team1, dtype: object

# %%
df['team1']=df['team1'].fillna(df['team1'].mode()[0])

# %%
df.isna().sum()
# Out:
# season             0
# team1              0
# team2              1
# date               0
# match_number       0
# venue              0
# city               0
# toss_winner        0
# toss_decision      0
# player_of_match    1
# umpire1            0
# umpire2            0
# reserve_umpire     0
# match_referee      0
# winner             0
# winner_runs        0
# winner_wickets     0
# match_type         0
# dtype: int64

# %%
df['team2'].mode()
# Out:
# 0    ENG
# Name: team2, dtype: object

# %%
df['team2']=df['team2'].fillna(df['team2'].mode()[0])

# %%
df.isna().sum()
# Out:
# season             0
# team1              0
# team2              0
# date               0
# match_number       0
# venue              0
# city               0
# toss_winner        0
# toss_decision      0
# player_of_match    1
# umpire1            0
# umpire2            0
# reserve_umpire     0
# match_referee      0
# winner             0
# winner_runs        0
# winner_wickets     0
# match_type         0
# dtype: int64

# %%
df['player_of_match'].mode()
# Out:
# 0             A Zampa
# 1           AU Rashid
# 2    Fazalhaq Farooqi
# 3           JJ Bumrah
# 4          MP Stoinis
# 5           Q de Kock
# 6            RL Chase
# 7            T Shamsi
# Name: player_of_match, dtype: object

# %%
df['player_of_match']=df['player_of_match'].fillna(df['player_of_match'].mode()[0])

# %%
df.isna().sum()
# Out:
# season             0
# team1              0
# team2              0
# date               0
# match_number       0
# venue              0
# city               0
# toss_winner        0
# toss_decision      0
# player_of_match    0
# umpire1            0
# umpire2            0
# reserve_umpire     0
# match_referee      0
# winner             0
# winner_runs        0
# winner_wickets     0
# match_type         0
# dtype: int64

# %%
df.drop(labels=['match_number', 'umpire1', 'umpire2', 'reserve_umpire', 'match_referee', 'venue'],axis=1,inplace=True)

# %%
df.head(3)
# Out:
#    season team1    team2      date        city toss_winner toss_decision  \
# 0    2024    CA      USA  6/1/2024      Dallas         USA         field
# 1    2024   PNG       WI  6/2/2024  Providence          WI         field
# 2    2024  Oman  Namibia  6/2/2024  Bridgetown     Namibia         field
#
#   player_of_match winner  winner_runs  winner_wickets match_type
# 0     Aaron Jones    USA         25.0             7.0      Group
# 1        RL Chase    WI          25.0             5.0      Group
# 2         D Wiese   IND          25.0             7.0      Group

# %%
df.columns
# Out:
# Index(['season', 'team1', 'team2', 'date', 'city', 'toss_winner',
#        'toss_decision', 'player_of_match', 'winner', 'winner_runs',
#        'winner_wickets', 'match_type'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   season           52 non-null     int64
#  1   team1            52 non-null     object
#  2   team2            52 non-null     object
#  3   date             52 non-null     object
#  4   city             52 non-null     object
#  5   toss_winner      52 non-null     object
#  6   toss_decision    52 non-null     object
#  7   player_of_match  52 non-null     object
#  8   winner           52 non-null     object
#  9   winner_runs      52 non-null     float64
#  10  winner_wickets   52 non-null     float64
#  11  match_type       52 non-null     object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 5.0+ KB

# %%
df = pd.concat([df, pd.get_dummies(df['city'], drop_first=True)], axis=1)
df.drop(columns=['city'], inplace=True)

# %%
df.head()
# Out:
#    season team1    team2      date toss_winner toss_decision  \
# 0    2024    CA      USA  6/1/2024         USA         field
# 1    2024   PNG       WI  6/2/2024          WI         field
# 2    2024  Oman  Namibia  6/2/2024     Namibia         field
# 3    2024    SL       SA  6/3/2024          SL           bat
# 4    2024   AFG   Uganda  6/3/2024      Uganda         field
#
#     player_of_match winner  winner_runs  winner_wickets match_type  Dallas  \
# 0       Aaron Jones    USA         25.0             7.0      Group    True
# 1          RL Chase    WI          25.0             5.0      Group   False
# 2           D Wiese   IND          25.0             7.0      Group   False
# 3          A Nortje     SA         25.0             6.0      Group   False
# 4  Fazalhaq Farooqi    AFG        125.0             7.0      Group   False
#
#    Gros Islet  Kingstown  Lauderhill  New York  North Sound  Providence  \
# ...

# %%
sns.heatmap(df.select_dtypes(include=['number']).corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(df.select_dtypes(include=['number']).corr(), annot=True)
plt.show()

# %%
x=['team1','city',' team2','date ']
y=np.array([3,4,5,8])
plt.pie(y,labels=x)
plt.show()
